# %% [markdown]
# # 𝖯𝖱𝖤𝖣𝖨𝖢𝖳𝖨𝖵𝖤 𝖬𝖠𝖨𝖭𝖳𝖤𝖭𝖠𝖭𝖢𝖤 𝖠𝖭𝖠𝖫𝖸𝖲𝖨S

# %%
from IPython.display import Image
Image(filename=r"C:\Users\saksh\Downloads\tool wear 1.jpg", width=1100, height=500)

# %% [raw]
# Key Points:
# Purpose of the Dataset: This dataset is used to analyze and predict failures in a manufacturing process based on various operational parameters.
#
# Applications: The data is used for predictive maintenance, quality control, and process optimization to reduce failures and improve efficiency
#
# ⚪'Dataset is taken from Kaggle website'

# %%
import numpy as np                  #numerical computing in Python
import pandas as pd                 # data manipulation and analysis.
import matplotlib.pyplot as plt     #plotting library
import seaborn as sns               #data visualization library

# %%
df = pd.read_csv(r"C:\Users\saksh\Downloads\predictive_maintenance - predictive_maintenance (1).csv")
df
# Out:
#         UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0         1     M14860    M                298.1                    308.6
# 1         2     L47181    L                298.2                    308.7
# 2         3     L47182    L                298.1                    308.5
# 3         4     L47183    L                298.2                    308.6
# 4         5     L47184    L                298.2                    308.7
# ...     ...        ...  ...                  ...                      ...
# 9995   9996     M24855    M                298.8                    308.4
# 9996   9997     H39410    H                298.9                    308.4
# 9997   9998     M24857    M                299.0                    308.6
# 9998   9999     H39412    H                299.0                    308.7
# 9999  10000     M24859    M                299.0                    308.7
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target  \
# ...

# %% [markdown]
# ## Data Description

# %% [markdown]
# - The columns consist values of:
#     1. Air temperature in Kelvin (K)
#     2. Process temperature in Kelvin (K)
#     3. Rotational speed in Rotation per minute (RPM)
#     4. Torque in Newton meters (Nm)
#     5. Tool wear in minutes (min)
#
#
# - Type column is given to represent the type of product with respect to its quality.
# >L, M and H are for Low, Medium and High quality products respectively.
#
# - The target column is the output of machine, if it is failing or not.
# >0 represents no failure whereas 1 represents that failure has occured.
#
# - An additional column of Failure Type is given so that we can understand what type of failure is occuring.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   UDI                      10000 non-null  int64
#  1   Product ID               10000 non-null  object
#  2   Type                     10000 non-null  object
#  3   Air temperature [K]      10000 non-null  float64
#  4   Process temperature [K]  10000 non-null  float64
#  5   Rotational speed [rpm]   10000 non-null  int64
#  6   Torque [Nm]              10000 non-null  float64
#  7   Tool wear [min]          10000 non-null  int64
#  8   Target                   10000 non-null  int64
#  9   Failure Type             10000 non-null  object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 781.4+ KB

# %%
df.describe()
# Out:
#                UDI  Air temperature [K]  Process temperature [K]  \
# count  10000.00000         10000.000000             10000.000000
# mean    5000.50000           300.004930               310.005560
# std     2886.89568             2.000259                 1.483734
# min        1.00000           295.300000               305.700000
# 25%     2500.75000           298.300000               308.800000
# 50%     5000.50000           300.100000               310.100000
# 75%     7500.25000           301.500000               311.100000
# max    10000.00000           304.500000               313.800000
#
#        Rotational speed [rpm]   Torque [Nm]  Tool wear [min]        Target
# count            10000.000000  10000.000000     10000.000000  10000.000000
# mean              1538.776100     39.986910       107.951000      0.033900
# std                179.284096      9.968934        63.654147      0.180981
# min               1168.000000      3.800000         0.000000      0.000000
# ...

# %% [raw]
# The mean and median values for several variables (Air temperature, Process temperature, Rotational speed, Torque, and Tool wear) are indeed close to each other, which suggests that these variables are approximately normally distributed.
#
# 1) Air temperature: Mean =
# 300.004930 K, Median = 300.1 K
# 2) Process temperature:
# Mean = 310.005560 K, Median = 310.1 K
# 3) Rotational speed: Mean =
# 1538.776100 rpm, Median = 1503 rpm
# 4) Torque: Mean =
# 39.986910 Nm, Median = 40.1 Nm
# 5) Tool wear: Mean =
# 107.951000 min, Median = 108 min

# %%
df
# Out:
#         UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0         1     M14860    M                298.1                    308.6
# 1         2     L47181    L                298.2                    308.7
# 2         3     L47182    L                298.1                    308.5
# 3         4     L47183    L                298.2                    308.6
# 4         5     L47184    L                298.2                    308.7
# ...     ...        ...  ...                  ...                      ...
# 9995   9996     M24855    M                298.8                    308.4
# 9996   9997     H39410    H                298.9                    308.4
# 9997   9998     M24857    M                299.0                    308.6
# 9998   9999     H39412    H                299.0                    308.7
# 9999  10000     M24859    M                299.0                    308.7
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target  \
# ...

# %% [markdown]
# ## ▷ 1. CORRELATION - HEATMAP

# %%
numeric_df = df.select_dtypes(include='number')
corr = numeric_df.corr()     # pairwise correllation

plt.figure(figsize=(10, 4))
heatmap = sns.heatmap(corr, annot=True, fmt=".2f", cmap='seismic', cbar=True)
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [raw]
# 1) Air temperature [K]:
# Correlation: 0.08 (very weak positive correlation) with the target.
# 2) Process temperature [K]:
# Correlation: 0.04 (very weak positive correlation) with the target.
# 3) Rotational speed [rpm]:
# Correlation: -0.04 (very weak negative correlation) with the target.
# 4) Torque [Nm]:
# Correlation: 0.19 (weak positive correlation) with the target.
# 5) Tool wear [min]:
# Correlation: 0.11 (weak positive correlation) with the target.

# %% [markdown]
# ## 2. PIE CHART FOR TARGET VARIABLE

# %%
df['Target'].value_counts()    # occurance of unique values
# Out:
# Target
# 0    9661
# 1     339
# Name: count, dtype: int64

# %% [markdown]
# ⚪Tool failures 1
# ⚪No tool Failure 0

# %%
df['Target'].value_counts().plot.pie(explode=[0.1,0.1],  #"gap" between the slices of the pie chart.
autopct='%.1f%%',title="Machine Failure",colors = ['gray', 'red' ] )
# Out:
# <Axes: title={'center': 'Machine Failure'}, ylabel='count'>

# %% [raw]
# ⚪Tool failures occur only 3.4% of the time.
# ⚪No tool Failure is occured 96.6% of time.

# %% [markdown]
# ## 3. FAILURE TYPES

# %%
failure_type_counts = df['Failure Type'].value_counts()
failure_type_counts.columns = ['Failure Type', 'Count']

failure_type_table = pd.DataFrame(failure_type_counts)
print(failure_type_table)
# Out:
#                           count
# Failure Type
# No Failure                 9652
# Heat Dissipation Failure    112
# Power Failure                95
# Overstrain Failure           78
# Tool Wear Failure            45
# Random Failures              18

# %% [markdown]
# ⚪ This summary provides a clear and brief overview of the failure types and their respective counts.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15, 4))
sns.countplot(data=df[df['Target'] == 1], y="Failure Type", hue="Failure Type", palette="inferno", legend=False)
plt.title("Count of Failures W.R.T Failure Types")
plt.xlabel('Count')
plt.ylabel('Failure Type')
plt.show()

# %% [raw]
# ⚪The chart displays the count of different failure types in the dataset.
# ⚪Heat Dissipation Failure is the most common type, with approximately 112 occurrences.
# ⚪Power Failure and Overstrain Failure are also significant, with around 90 and 80 occurrences respectively.
# ⚪Tool Wear Failure has approximately 60 occurrences.
# ⚪No Failure is the least common, with about 20 occurrences

# %% [markdown]
# ## 4. FEATURE IMPORTANCE

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder

# Encoding categorical variables
label_encoder = LabelEncoder()   #categorical data converted into numerical data
df['Product ID'] = label_encoder.fit_transform(df['Product ID'])
df['Type'] = label_encoder.fit_transform(df['Type'])
df['Failure Type'] = label_encoder.fit_transform(df['Failure Type'])

# Define features and target
features = df.drop('Target', axis=1)
target = df['Target']

# Train the model
model = RandomForestClassifier()
model.fit(features, target)

# Plot feature importances
feature_importances = pd.Series(model.feature_importances_, index=features.columns)
feature_importances.nlargest(10).plot(kind='barh', color='gray')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Top 10 Feature Importances')
plt.show()

# %% [markdown]
# ⚪The visual shows which features are most influential in making predictions.
# ⚪This helps in understanding how the model makes decisions.

# %% [markdown]
# ## 5. Low, Medium and High quality products

# %%
pd.DataFrame(df["Type"].value_counts())
# Out:
#       count
# Type
# 1      6000
# 2      2997
# 0      1003

# %%
df['Type'].value_counts().plot.pie(autopct='%.f%%', 
colors= ['gray', 'pink', 'green'], title="Percentage of Product Types")
# Out:
# <Axes: title={'center': 'Percentage of Product Types'}, ylabel='count'>

# %% [markdown]
# ⚪the quality distribution of your products:
#
# 1) Low Quality: Around 60%
# 2) Medium Quality: About 30%
# 3) High Quality: 10%
#
# This format provides a clear overview of the product quality categories.

# %% [markdown]
# ## 6. DATA DISTRIBUTION

# %%
colors = {
    'Air temperature [K]': 'orange',
    'Process temperature [K]': 'brown',
    'Rotational speed [rpm]': 'pink',
    'Torque [Nm]': 'green',
    'Tool wear [min]': 'purple'
}

for col in colors:
    plt.figure(figsize=(20, 4))
    sns.histplot(df[col], kde=True, color=colors[col])
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.show()

# %% [markdown]
# 1)  it uses a smooth, continuous curve to represent the distribution.
# 2) It provides a better visual representation of the distribution's shape, especially with small sample sizes.
# 3) This aids in understanding the spread and central tendencies of the data,
# such as whether the data is normally distributed, skewed.

# %%
df.drop(['UDI','Product ID','Failure Type'],axis=1,inplace=True)

# %% [markdown]
# Dropping the columns 'UDI', 'Product ID', and 'Failure Type' from DataFrame can help focus on the most relevant features for modeling

# %%
print(df.columns)
# Out:
# Index(['Type', 'Air temperature [K]', 'Process temperature [K]',
#        'Rotational speed [rpm]', 'Torque [Nm]', 'Tool wear [min]', 'Target'],
#       dtype='object')

# %% [markdown]
# ##### Replacing the 'type' column which is categorical values of Type column into numeric values.

# %%
df["Type"] = df["Type"].replace("L",0)
df["Type"] = df["Type"].replace("M",1)
df["Type"] = df["Type"].replace("H",2)

# %%
df.head()
# Out:
#    Type  Air temperature [K]  Process temperature [K]  Rotational speed [rpm]  \
# 0     2                298.1                    308.6                    1551
# 1     1                298.2                    308.7                    1408
# 2     1                298.1                    308.5                    1498
# 3     1                298.2                    308.6                    1433
# 4     1                298.2                    308.7                    1408
#
#    Torque [Nm]  Tool wear [min]  Target
# 0         42.8                0       0
# 1         46.3                3       0
# 2         49.4                5       0
# 3         39.5                7       0
# 4         40.0                9       0

# %%
predictors = df.iloc[:,:-1]
predictors
# Out:
#       Type  Air temperature [K]  Process temperature [K]  \
# 0        2                298.1                    308.6
# 1        1                298.2                    308.7
# 2        1                298.1                    308.5
# 3        1                298.2                    308.6
# 4        1                298.2                    308.7
# ...    ...                  ...                      ...
# 9995     2                298.8                    308.4
# 9996     0                298.9                    308.4
# 9997     2                299.0                    308.6
# 9998     0                299.0                    308.7
# 9999     2                299.0                    308.7
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]
# 0                       1551         42.8                0
# 1                       1408         46.3                3
# 2                       1498         49.4                5
# ...

# %%
label = df.iloc[:,-1]
label
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    0
# 9998    0
# 9999    0
# Name: Target, Length: 10000, dtype: int64

# %% [markdown]
# ## SMOTE TECHNIQUE

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(sampling_strategy="minority")
predictors,label = smote.fit_resample(predictors, label)
label.value_counts()
# Out:
# Target
# 0    9661
# 1    9661
# Name: count, dtype: int64

# %% [markdown]
# ## Why Use SMOTE?

# %% [markdown]
# SMOTE helps in addressing the issue of class imbalance in your dataset by generating synthetic examples for the minority class. This can lead to better performance of machine learning models, as they can learn more effectively from a balanced dataset.

# %% [markdown]
# ## ▷ SPLITTING DATA INTO TRAIN AND TEST FORMATE

# %% [markdown]
# Here we created a function to check which Machine Learning Algorithm will be the best fit for our model. We will select the one with highest accuracy.

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(predictors,label,test_size=0.3,random_state=42)

from sklearn.linear_model import LogisticRegression                #LogisticRegression from sklearn.linear_model.
logreg = LogisticRegression()

from sklearn.neighbors import KNeighborsClassifier                 #KNeighborsClassifier from sklearn.neighbors
knn = KNeighborsClassifier()

from sklearn.tree import DecisionTreeClassifier                    #DecisionTreeClassifier from sklearn.tree
dt = DecisionTreeClassifier()

from sklearn.metrics import accuracy_score,classification_report   #This line imports the accuracy_score and classification_report functions

# %%
logreg = LogisticRegression()
knn = KNeighborsClassifier()
dt = DecisionTreeClassifier()
rf = RandomForestClassifier()
from sklearn.svm import SVC

# %%
from sklearn.metrics import classification_report,accuracy_score
def mymodel(model):
    model.fit(X_train,y_train)        #This line trains the model on the training data X_train and y_train
    y_pred = model.predict(X_test)    #This line uses the trained model to predict labels for the test data X_tes
 
    print("Accuracy Score :",accuracy_score(y_test,y_pred))
    print(classification_report(y_test,y_pred))
    
    train = model.score(X_train,y_train)
    test = model.score(X_test,y_test)
    print("Training Performance :",train)
    print("Testing Performance :",test)
    return model

# %% [markdown]
# ## MODELS EXECUTATION

# %%
mymodel(logreg)
# Out:
# Accuracy Score : 0.8414697257202001
#               precision    recall  f1-score   support
#
#            0       0.84      0.84      0.84      2901
#            1       0.84      0.84      0.84      2896
#
#     accuracy                           0.84      5797
#    macro avg       0.84      0.84      0.84      5797
# weighted avg       0.84      0.84      0.84      5797
#
# Training Performance : 0.8345286506469501
# Testing Performance : 0.8414697257202001
# LogisticRegression()

# %% [raw]
# Accuracy Score: This means that 84.01% true positive predictions made by the model are correct
# Precision: 0.84 indicates ratio of true positive predictions to the total predicted positives
# Recall: 0.84 shows the percentage of actual positives correctly identified by the model.

# %% [markdown]
# ## 3. Support Vector Machine

# %%
svm = SVC()
mymodel(svm)
# Out:
# Accuracy Score : 0.8359496291185096
#               precision    recall  f1-score   support
#
#            0       0.86      0.81      0.83      2901
#            1       0.82      0.86      0.84      2896
#
#     accuracy                           0.84      5797
#    macro avg       0.84      0.84      0.84      5797
# weighted avg       0.84      0.84      0.84      5797
#
# Training Performance : 0.8322365988909427
# Testing Performance : 0.8359496291185096
# SVC()

# %% [markdown]
# ## Decision Tree Classifier

# %%
mymodel(dt)
# Out:
# Accuracy Score : 0.9604968086941521
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96      2901
#            1       0.95      0.97      0.96      2896
#
#     accuracy                           0.96      5797
#    macro avg       0.96      0.96      0.96      5797
# weighted avg       0.96      0.96      0.96      5797
#
# Training Performance : 1.0
# Testing Performance : 0.9604968086941521
# DecisionTreeClassifier()

# %%
mymodel(rf)
# Out:
# Accuracy Score : 0.9736070381231672
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97      2901
#            1       0.96      0.98      0.97      2896
#
#     accuracy                           0.97      5797
#    macro avg       0.97      0.97      0.97      5797
# weighted avg       0.97      0.97      0.97      5797
#
# Training Performance : 1.0
# Testing Performance : 0.9736070381231672
# RandomForestClassifier()

# %%
from sklearn.ensemble import AdaBoostClassifier
from xgboost import XGBClassifier
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.metrics import classification_report
from sklearn.ensemble import GradientBoostingClassifier

# %% [markdown]
# ## TESTING RANDOM FOREST

# %%
def predtest():
    Type = int(input("Enter type of product based on quality.\nIf Low, enter 0.\nIf Medium, enter 1.\nIf High, enter 2.\nYou entered : "))
    Airtemp = eval(input("Enter Air Temperature in K : "))
    Protemp = eval(input("Enter Process Temperature in K : "))
    Rotsp = int(input("Enter Rotational Speed in RPM : "))
    Torq = eval(input("Enter Torque in Nm : "))
    Toolw = int(input("Enter Tool Wear in min : "))
    Tempdiff = Protemp-Airtemp
    
    newx = [Type,Airtemp,Protemp,Rotsp,Torq,Toolw]
    yp = rf.predict([newx])[0]
    
    if yp==1:
        print("Machine Failed")
        return yp
    else:
        print("Machine didn't Fail")
        return yp

# %% [markdown]
# >Example:-
# - Type = H
# - Air temperature [K] = 298.4
# - Process temperature [K] = 308.9
# - Rotational speed [rpm] = 1782
# - Torque [Nm] = 23.9
# - Tool wear [min] = 24
# - Target = 0

# %% [markdown]
# >Example:-
# - Type = M
# - Air temperature [K] = 298.2
# - Process temperature [K] = 308.5
# - Rotational speed [rpm] = 2678
# - Torque [Nm] = 10.7
# - Tool wear [min] = 86
# - Target = 1

# %%
predtest()

# %% [raw]
# Measures to Avoid Machine Failure:
#
# 1) Set Proper Rotational Speed: Ensure the rotational speed is neither too high nor too low.
#
# 2) Adjust Torque Correctly: Torque should match the tool’s requirements—avoid setting it too high or too low.
#
# 3) Rotate Tools Regularly: Do not use the same tool for an extended period to prevent wear and tear.
#
# 4) Use Quality Products: Prefer high and medium quality products for better performance.
#
# 5) Prevent Overheating: Continuously provide coolant to the tool to avoid overheating.
#
# 6) Provide Backup Power: Have a secondary power source ready in case of power failure.
